# %% [markdown]
# <a href="https://colab.research.google.com/github/TeamTenacity46/Data-Analysis/blob/master/TransformingTrainFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import some libraries that will be used
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#mount to google drive, to retrieve files from it
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#import train.csv into a dataframe called train
train = pd.read_csv('/content/drive/My Drive/Colab Notebooks/train.csv')

# %%
#check that calling train works
train.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
#show the number of rows and collumns in the dataframe
train.shape
# Out:
# (1460, 81)

# %%
#check for missing values in test
#and print them sorted
missing_values = train.isnull().sum()
missing_values = missing_values[missing_values!=0].dropna()
print(missing_values.sort_values())
# Out:
# Electrical         1
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# BsmtExposure      38
# BsmtFinType2      38
# GarageCond        81
# GarageQual        81
# GarageFinish      81
# GarageType        81
# GarageYrBlt       81
# LotFrontage      259
# FireplaceQu      690
# Fence           1179
# Alley           1369
# MiscFeature     1406
# PoolQC          1453
# dtype: int64

# %%
train['LotFrontage']=train['LotFrontage'].fillna(train['LotFrontage'].mean())
train['GarageYrBlt']=train['GarageYrBlt'].fillna(train['GarageYrBlt'].mean())
train['MasVnrArea']=train['MasVnrArea'].fillna(train['MasVnrArea'].mean())


train['FireplaceQu']=train['FireplaceQu'].fillna(train['FireplaceQu'].mode()[0])
train['GarageCond']=train['GarageCond'].fillna(train['GarageCond'].mode()[0])
train['GarageQual']=train['GarageQual'].fillna(train['GarageQual'].mode()[0])
train['GarageFinish']=train['GarageFinish'].fillna(train['GarageFinish'].mode()[0])
train['GarageType']=train['GarageType'].fillna(train['GarageType'].mode()[0])
train['BsmtFinType1']=train['BsmtFinType1'].fillna(train['BsmtFinType1'].mode()[0])
train['BsmtFinType2']=train['BsmtFinType2'].fillna(train['BsmtFinType2'].mode()[0])
train['BsmtExposure']=train['BsmtExposure'].fillna(train['BsmtExposure'].mode()[0])
train['BsmtCond']=train['BsmtCond'].fillna(train['BsmtCond'].mode()[0])
train['BsmtQual']=train['BsmtQual'].fillna(train['BsmtQual'].mode()[0])
train['MasVnrType']=train['MasVnrType'].fillna(train['MasVnrType'].mode()[0])
train['Electrical']=train['Electrical'].fillna(train['MasVnrType'].mode()[0])

# %%
#delete the last columns with missing values (Fence, Alley, MiscFeature, PoolQC)
#removed because of to many missing values
train = train.dropna(axis='columns')

#remove Id, not needed for the prediction
train = train.drop(['Id'],axis='columns')

# %%
train['MSZoning'] = train['MSZoning'].astype('category')
train['Street'] = train['Street'].astype('category')
train['LotShape'] = train['LotShape'].astype('category')
train['LandContour'] = train['LandContour'].astype('category')
train['Utilities'] = train['Utilities'].astype('category')
train['LotConfig'] = train['LotConfig'].astype('category')
train['LandSlope'] = train['LandSlope'].astype('category')
train['Neighborhood'] = train['Neighborhood'].astype('category')
train['Condition1'] = train['Condition1'].astype('category')
train['Condition2'] = train['Condition2'].astype('category')
train['BldgType'] = train['BldgType'].astype('category')
train['HouseStyle'] = train['HouseStyle'].astype('category')
train['RoofStyle'] = train['RoofStyle'].astype('category')
train['RoofMatl'] = train['RoofMatl'].astype('category')
train['Exterior1st'] = train['Exterior1st'].astype('category')
train['Exterior2nd'] = train['Exterior2nd'].astype('category')
train['MasVnrType'] = train['MasVnrType'].astype('category')
train['ExterQual'] = train['ExterQual'].astype('category')
train['ExterCond'] = train['ExterCond'].astype('category')
train['Foundation'] = train['Foundation'].astype('category')
train['BsmtQual'] = train['BsmtQual'].astype('category')
train['BsmtCond'] = train['BsmtCond'].astype('category')
train['BsmtExposure'] = train['BsmtExposure'].astype('category')
train['BsmtFinType1'] = train['BsmtFinType1'].astype('category')
train['BsmtFinType2'] = train['BsmtFinType2'].astype('category')
train['Heating'] = train['Heating'].astype('category')
train['HeatingQC'] = train['HeatingQC'].astype('category')
train['CentralAir'] = train['CentralAir'].astype('category')
train['Electrical'] = train['Electrical'].astype('category')
train['KitchenQual'] = train['KitchenQual'].astype('category')
train['Functional'] = train['Functional'].astype('category')
train['GarageType'] = train['GarageType'].astype('category')
train['GarageFinish'] = train['GarageFinish'].astype('category')
train['GarageQual'] = train['GarageQual'].astype('category')
train['GarageCond'] = train['GarageCond'].astype('category')
train['PavedDrive'] = train['PavedDrive'].astype('category')
train['SaleType'] = train['SaleType'].astype('category')
train['SaleCondition'] = train['SaleCondition'].astype('category')
train['FireplaceQu'] = train['FireplaceQu'].astype('category')

# %%
train['MSZoning'] = train['MSZoning'].cat.codes
train['Street'] = train['Street'].cat.codes
train['LotShape'] = train['LotShape'].cat.codes
train['LandContour'] = train['LandContour'].cat.codes
train['Utilities'] = train['Utilities'].cat.codes
train['LotConfig'] = train['LotConfig'].cat.codes
train['LandSlope'] = train['LandSlope'].cat.codes
train['Neighborhood'] = train['Neighborhood'].cat.codes
train['Condition1'] = train['Condition1'].cat.codes
train['Condition2'] = train['Condition2'].cat.codes
train['BldgType'] = train['BldgType'].cat.codes
train['HouseStyle'] = train['HouseStyle'].cat.codes
train['RoofStyle'] = train['RoofStyle'].cat.codes
train['RoofMatl'] = train['RoofMatl'].cat.codes
train['Exterior1st'] = train['Exterior1st'].cat.codes
train['Exterior2nd'] = train['Exterior2nd'].cat.codes
train['MasVnrType'] = train['MasVnrType'].cat.codes
train['ExterQual'] = train['ExterQual'].cat.codes
train['ExterCond'] = train['ExterCond'].cat.codes
train['Foundation'] = train['Foundation'].cat.codes
train['BsmtQual'] = train['BsmtQual'].cat.codes
train['BsmtCond'] = train['BsmtCond'].cat.codes
train['BsmtExposure'] = train['BsmtExposure'].cat.codes
train['BsmtFinType1'] = train['BsmtFinType1'].cat.codes
train['BsmtFinType2'] = train['BsmtFinType2'].cat.codes
train['Heating'] = train['Heating'].cat.codes
train['HeatingQC'] = train['HeatingQC'].cat.codes
train['CentralAir'] = train['CentralAir'].cat.codes
train['Electrical'] = train['Electrical'].cat.codes
train['KitchenQual'] = train['KitchenQual'].cat.codes
train['Functional'] = train['Functional'].cat.codes
train['GarageType'] = train['GarageType'].cat.codes
train['GarageFinish'] = train['GarageFinish'].cat.codes
train['GarageQual'] = train['GarageQual'].cat.codes
train['GarageCond'] = train['GarageCond'].cat.codes
train['PavedDrive'] = train['PavedDrive'].cat.codes
train['SaleType'] = train['SaleType'].cat.codes
train['SaleCondition'] = train['SaleCondition'].cat.codes
train['FireplaceQu'] = train['FireplaceQu'].cat.codes

# %%
#export the transformed data to another csv file
train.to_csv('trainFormulated.csv',index=False)
